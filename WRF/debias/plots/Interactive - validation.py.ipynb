# %% [markdown]
# Connected to olympics (Python 3.11.15)

# %%
"""
Author: Sydney Smith
Date Created: August 25, 2026
"""

from datetime import datetime
import glob
from loguru import logger
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from pathlib import Path
import sys
import xarray as xr

# ==================================
# - Establish Relative File Path - 
# ==================================

current_dir = Path(__file__).resolve().parent
parent_dir = current_dir.parent

# Import custom python modules from other directories
sys.path.append(str(parent_dir.parent.parent))
from from_savanna.nclcmaps import cmap

sys.path.append(str(parent_dir))
from old.temporal_chunks import open_or_skip, get_fpaths

sys.path.append(str(current_dir))
from spatial_chunks import fix_time_coord

obs_path = glob.glob(str(parent_dir / 'gridMET' / f'*{var}*.nc'))
obs = xr.open_dataset(obs_path[0], decode_times = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 35
#      32 sys.path.append(str(current_dir))
#      33 from spatial_chunks import fix_time_coord
# ---> 35 obs_path = glob.glob(str(parent_dir / 'gridMET' / f'*{var}*.nc'))
#      36 obs = xr.open_dataset(obs_path[0], decode_times = False)
#
# NameError: name 'var' is not defined

# %%
"""
Author: Sydney Smith
Date Created: August 25, 2026
"""

from datetime import datetime
import glob
from loguru import logger
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from pathlib import Path
import sys
import xarray as xr

# ==================================
# - Establish Relative File Path - 
# ==================================

current_dir = Path(__file__).resolve().parent
parent_dir = current_dir.parent

# Import custom python modules from other directories
sys.path.append(str(parent_dir.parent.parent))
from from_savanna.nclcmaps import cmap

sys.path.append(str(parent_dir))
from old.temporal_chunks import open_or_skip, get_fpaths

sys.path.append(str(current_dir))
from spatial_chunks import fix_time_coord

var = 'tmmn'
obs_path = glob.glob(str(parent_dir / 'gridMET' / f'*{var}*.nc'))
obs = xr.open_dataset(obs_path[0], decode_times = False)

# %%
obs
# Out:
# <xarray.Dataset> Size: 159GB
# Dimensions:  (time: 21914, lat: 111, lon: 90, south_north: 111, east_west: 90,
#               west_east: 90)
# Coordinates:
#   * time     (time) int64 175kB 0 0 1 1 2 2 ... 10954 10955 10955 10956 10956
#     lat      (time, south_north, east_west, west_east) float32 79GB ...
#     lon      (time, south_north, east_west, west_east) float32 79GB ...
# Dimensions without coordinates: south_north, east_west, west_east
# Data variables:
#     tmmn     (time, lat, lon) float64 2GB ...

# %%
obs.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 obs.shape
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/common.py:306, in AttrAccessMixin.__getattr__(self, name)
#     304         with suppress(KeyError):
#     305             return source[name]
# --> 306 raise AttributeError(
#     307     f"{type(self).__name__!r} object has no attribute {name!r}"
#     308 )
#
# AttributeError: 'Dataset' object has no attribute 'shape'

# %%
obs.size
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 obs.size
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/common.py:306, in AttrAccessMixin.__getattr__(self, name)
#     304         with suppress(KeyError):
#     305             return source[name]
# --> 306 raise AttributeError(
#     307     f"{type(self).__name__!r} object has no attribute {name!r}"
#     308 )
#
# AttributeError: 'Dataset' object has no attribute 'size'

# %%
obs['tmmn'].shape
# Out:
# (21914, 111, 90)

# %%
"""
Author: Sydney Smith
Date Created: August 25, 2026
"""

from datetime import datetime
import glob
from loguru import logger
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from pathlib import Path
import sys
import xarray as xr

# ==================================
# - Establish Relative File Path - 
# ==================================

current_dir = Path(__file__).resolve().parent
parent_dir = current_dir.parent

# Import custom python modules from other directories
sys.path.append(str(parent_dir.parent.parent))
from from_savanna.nclcmaps import cmap

sys.path.append(str(parent_dir))
from old.temporal_chunks import open_or_skip, get_fpaths

sys.path.append(str(current_dir))
from spatial_chunks import fix_time_coord

var = 'tmmn'
obs_path = glob.glob(str(parent_dir / 'gridMET' / f'*{var}*.nc'))
ds = xr.open_dataset(obs_path[0], decode_times = False)

# Select single array along time dim to reduce ds size
lat_2d = ds.isel(time = 0, drop = True)
lon_2d = ds.isel(time = 0, drop = True)

# Find the vector distance from the coordinates passed to every coordinate pair on the dataset's grid
dist = (lat_2d - (lat)) ** 2 + (lon_2d - (lon)) ** 2

# Find the min distance and pull out its x and y index values
dist_min = np.argmin(dist)
logger.info(f'Point selected is {dist_min} from {lat}, {lon}.')
y_idx, x_idx = np.unravel_index(dist_min, dist.shape)
logger.info(f'Min distance is located at {x_idx}, {y_idx}.')

# SPull grid's spatial dims dynamically
spatial_dims = ds['lat'].dims

# Select min distance grid point using isel
point_data = ds.isel({
    spatial_dims[0]: y_idx,
    spatial_dims[1]: x_idx
}).squeeze()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 44
#      41 lon_2d = ds.isel(time = 0, drop = True)
#      43 # Find the vector distance from the coordinates passed to every coordinate pair on the dataset's grid
# ---> 44 dist = (lat_2d - (lat)) ** 2 + (lon_2d - (lon)) ** 2
#      46 # Find the min distance and pull out its x and y index values
#      47 dist_min = np.argmin(dist)
#
# NameError: name 'lat' is not defined

# %%
"""
Author: Sydney Smith
Date Created: August 25, 2026
"""

from datetime import datetime
import glob
from loguru import logger
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from pathlib import Path
import sys
import xarray as xr

# ==================================
# - Establish Relative File Path - 
# ==================================

current_dir = Path(__file__).resolve().parent
parent_dir = current_dir.parent

# Import custom python modules from other directories
sys.path.append(str(parent_dir.parent.parent))
from from_savanna.nclcmaps import cmap

sys.path.append(str(parent_dir))
from old.temporal_chunks import open_or_skip, get_fpaths

sys.path.append(str(current_dir))
from spatial_chunks import fix_time_coord

var = 'tmmn'
obs_path = glob.glob(str(parent_dir / 'gridMET' / f'*{var}*.nc'))
ds = xr.open_dataset(obs_path[0], decode_times = False)

lat = 40.788
lon = -111.978

# Select single array along time dim to reduce ds size
lat_2d = ds.isel(time = 0, drop = True)
lon_2d = ds.isel(time = 0, drop = True)

# Find the vector distance from the coordinates passed to every coordinate pair on the dataset's grid
dist = (lat_2d - (lat)) ** 2 + (lon_2d - (lon)) ** 2

# Find the min distance and pull out its x and y index values
dist_min = np.argmin(dist)
logger.info(f'Point selected is {dist_min} from {lat}, {lon}.')
y_idx, x_idx = np.unravel_index(dist_min, dist.shape)
logger.info(f'Min distance is located at {x_idx}, {y_idx}.')

# SPull grid's spatial dims dynamically
spatial_dims = ds['lat'].dims

# Select min distance grid point using isel
point_data = ds.isel({
    spatial_dims[0]: y_idx,
    spatial_dims[1]: x_idx
}).squeeze()
# Out:
# /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:54: FutureWarning: Once the behaviour of DataArray.argmin() and Variable.argmin() without dim changes to return a dict of indices of each dimension, for consistency it will be an error to call Dataset.argmin() with no argument,since we don't return a dict of Datasets.
#   return bound(*args, **kwds)
# 20:56:11 |     INFO | __main__:<module>:line 51 - Point selected is <xarray.Dataset> Size: 8B
# Dimensions:  ()
# Data variables:
#     tmmn     int64 8B 9979 from 40.788, -111.978.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 52
#      50 dist_min = np.argmin(dist)
#      51 logger.info(f'Point selected is {dist_min} from {lat}, {lon}.')
# ---> 52 y_idx, x_idx = np.unravel_index(dist_min, dist.shape)
#      53 logger.info(f'Min distance is located at {x_idx}, {y_idx}.')
#      55 # SPull grid's spatial dims dynamically
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/common.py:306, in AttrAccessMixin.__getattr__(self, name)
#     304         with suppress(KeyError):
#     305             return source[name]
# --> 306 raise AttributeError(
#     307     f"{type(self).__name__!r} object has no attribute {name!r}"
#     308 )
#
# AttributeError: 'Dataset' object has no attribute 'shape'

# %%
dist
# Out:
# <xarray.Dataset> Size: 7MB
# Dimensions:  (south_north: 111, east_west: 90, west_east: 90, lat: 111, lon: 90)
# Coordinates:
#     lat      (south_north, east_west, west_east) float32 4MB 39.22 ... 43.18
#     lon      (south_north, east_west, west_east) float32 4MB -114.1 ... -109.9
# Dimensions without coordinates: south_north, east_west, west_east
# Data variables:
#     tmmn     (lat, lon) float64 80kB 1.872e+05 1.875e+05 ... 1.673e+05 1.684e+05

# %%
"""
Author: Sydney Smith
Date Created: August 25, 2026
"""

from datetime import datetime
import glob
from loguru import logger
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from pathlib import Path
import sys
import xarray as xr

# ==================================
# - Establish Relative File Path - 
# ==================================

current_dir = Path(__file__).resolve().parent
parent_dir = current_dir.parent

# Import custom python modules from other directories
sys.path.append(str(parent_dir.parent.parent))
from from_savanna.nclcmaps import cmap

sys.path.append(str(parent_dir))
from old.temporal_chunks import open_or_skip, get_fpaths

sys.path.append(str(current_dir))
from spatial_chunks import fix_time_coord

var = 'tmmn'
obs_path = glob.glob(str(parent_dir / 'gridMET' / f'*{var}*.nc'))
ds = xr.open_dataset(obs_path[0], decode_times = False)

lat = 40.788
lon = -111.978

# Select single array along time dim to reduce ds size
lat_2d = ds[var].isel(time = 0, drop = True)
lon_2d = ds[var].isel(time = 0, drop = True)

# Find the vector distance from the coordinates passed to every coordinate pair on the dataset's grid
dist = (lat_2d - (lat)) ** 2 + (lon_2d - (lon)) ** 2

# Find the min distance and pull out its x and y index values
dist_min = np.argmin(dist)
logger.info(f'Point selected is {dist_min} from {lat}, {lon}.')
y_idx, x_idx = np.unravel_index(dist_min, dist.shape)
logger.info(f'Min distance is located at {x_idx}, {y_idx}.')

# SPull grid's spatial dims dynamically
spatial_dims = ds['lat'].dims

# Select min distance grid point using isel
point_data = ds.isel({
    spatial_dims[0]: y_idx,
    spatial_dims[1]: x_idx
}).squeeze()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:54, in _wrapfunc(obj, method, *args, **kwds)
#      53 try:
# ---> 54     return bound(*args, **kwds)
#      55 except TypeError:
#      56     # A TypeError occurs if the object does have such a method in its
#      57     # class, but its signature is not identical to that of NumPy's. This
#    (...)     61     # Call _wrapit from within the except clause to ensure a potential
#      62     # exception has a traceback chain.
#
# TypeError: DataArray.argmin() got an unexpected keyword argument 'out'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 50
#      47 dist = (lat_2d - (lat)) ** 2 + (lon_2d - (lon)) ** 2
#      49 # Find the min distance and pull out its x and y index values
# ---> 50 dist_min = np.argmin(dist)
#      51 logger.info(f'Point selected is {dist_min} from {lat}, {lon}.')
#      52 y_idx, x_idx = np.unravel_index(dist_min, dist.shape)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:1414, in argmin(a, axis, out, keepdims)
#    1323 """
#    1324 Returns the indices of the minimum values along an axis.
#    1325
#    (...)   1411 (2, 1, 4)
#    1412 """
#    1413 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1414 return _wrapfunc(a, 'argmin', axis=axis, out=out, **kwds)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:63, in _wrapfunc(obj, method, *args, **kwds)
#      54     return bound(*args, **kwds)
#      55 except TypeError:
#      56     # A TypeError occurs if the object does have such a method in its
#      57     # class, but its signature is not identical to that of NumPy's. This
#    (...)     61     # Call _wrapit from within the except clause to ensure a potential
#      62     # exception has a traceback chain.
# ---> 63     return _wrapit(obj, method, *args, **kwds)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:45, in _wrapit(obj, method, *args, **kwds)
#      42 arr, = conv.as_arrays(subok=False)
#      43 result = getattr(arr, method)(*args, **kwds)
# ---> 45 return conv.wrap(result, to_scalar=False)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/dataarray.py:4877, in DataArray.__array_wrap__(self, obj, context, return_scalar)
#    4876 def __array_wrap__(self, obj, context=None, return_scalar=False) -> Self:
# -> 4877     new_var = self.variable.__array_wrap__(obj, context, return_scalar)
#    4878     return self._replace(new_var)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/variable.py:2432, in Variable.__array_wrap__(self, obj, context, return_scalar)
#    2431 def __array_wrap__(self, obj, context=None, return_scalar=False):
# -> 2432     return Variable(self.dims, obj)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/variable.py:398, in Variable.__init__(self, dims, data, attrs, encoding, fastpath)
#     370 def __init__(
#     371     self,
#     372     dims,
#    (...)    376     fastpath=False,
#     377 ):
#     378     """
#     379     Parameters
#     380     ----------
#    (...)    396         unrecognized encoding items.
#     397     """
# --> 398     super().__init__(
#     399         dims=dims, data=as_compatible_data(data, fastpath=fastpath), attrs=attrs
#     400     )
#     402     self._encoding: dict[Any, Any] | None = None
#     403     if encoding is not None:
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/namedarray/core.py:261, in NamedArray.__init__(self, dims, data, attrs)
#     254 def __init__(
#     255     self,
#     256     dims: _DimsLike,
#     257     data: duckarray[Any, _DType_co],
#     258     attrs: _AttrsLike = None,
#     259 ):
#     260     self._data = data
# --> 261     self._dims = self._parse_dimensions(dims)
#     262     self._attrs = dict(attrs) if attrs else None
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/namedarray/core.py:505, in NamedArray._parse_dimensions(self, dims)
#     503 dims = (dims,) if isinstance(dims, str) else tuple(dims)
#     504 if len(dims) != self.ndim:
# --> 505     raise ValueError(
#     506         f"dimensions {dims} must have the same length as the "
#     507         f"number of data dimensions, ndim={self.ndim}"
#     508     )
#     509 if len(set(dims)) < len(dims):
#     510     repeated_dims = {d for d in dims if dims.count(d) > 1}
#
# ValueError: dimensions ('lat', 'lon') must have the same length as the number of data dimensions, ndim=0

# %%
dist
# Out:
# <xarray.DataArray 'tmmn' (lat: 111, lon: 90)> Size: 80kB
# array([[187219.30153138, 187464.75231886, 186427.41533223, ...,
#         188089.82895355, 187118.46478935, 187893.16236351],
#        [186587.78341134, 187232.69012382, 186687.80196483, ...,
#         186937.20918498, 186039.32796085, 186995.9890997 ],
#        [186227.44616008, 186988.32300968, 186343.90561145, ...,
#         185444.69040631, 184900.89864133, 186352.86738269],
#        ...,
#        [183815.75405522, 183731.98748553, 183769.29280911, ...,
#         167036.54168011, 167504.23920636, 169596.23774645],
#        [182754.11891886, 182597.54651803, 182573.05563337, ...,
#         165635.83213153, 167388.48137444, 169031.01911704],
#        [181926.59234799, 181720.38196904, 181740.37010886, ...,
#         164857.74957333, 167328.66835973, 168426.62795921]],
#       shape=(111, 90))
# Dimensions without coordinates: lat, lon

# %%
dist.shape
# Out:
# (111, 90)

# %%
np.argmin(dist)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:54, in _wrapfunc(obj, method, *args, **kwds)
#      53 try:
# ---> 54     return bound(*args, **kwds)
#      55 except TypeError:
#      56     # A TypeError occurs if the object does have such a method in its
#      57     # class, but its signature is not identical to that of NumPy's. This
#    (...)     61     # Call _wrapit from within the except clause to ensure a potential
#      62     # exception has a traceback chain.
#
# TypeError: DataArray.argmin() got an unexpected keyword argument 'out'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 np.argmin(dist)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:1414, in argmin(a, axis, out, keepdims)
#    1323 """
#    1324 Returns the indices of the minimum values along an axis.
#    1325
#    (...)   1411 (2, 1, 4)
#    1412 """
#    1413 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1414 return _wrapfunc(a, 'argmin', axis=axis, out=out, **kwds)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:63, in _wrapfunc(obj, method, *args, **kwds)
#      54     return bound(*args, **kwds)
#      55 except TypeError:
#      56     # A TypeError occurs if the object does have such a method in its
#      57     # class, but its signature is not identical to that of NumPy's. This
#    (...)     61     # Call _wrapit from within the except clause to ensure a potential
#      62     # exception has a traceback chain.
# ---> 63     return _wrapit(obj, method, *args, **kwds)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:45, in _wrapit(obj, method, *args, **kwds)
#      42 arr, = conv.as_arrays(subok=False)
#      43 result = getattr(arr, method)(*args, **kwds)
# ---> 45 return conv.wrap(result, to_scalar=False)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/dataarray.py:4877, in DataArray.__array_wrap__(self, obj, context, return_scalar)
#    4876 def __array_wrap__(self, obj, context=None, return_scalar=False) -> Self:
# -> 4877     new_var = self.variable.__array_wrap__(obj, context, return_scalar)
#    4878     return self._replace(new_var)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/variable.py:2432, in Variable.__array_wrap__(self, obj, context, return_scalar)
#    2431 def __array_wrap__(self, obj, context=None, return_scalar=False):
# -> 2432     return Variable(self.dims, obj)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/variable.py:398, in Variable.__init__(self, dims, data, attrs, encoding, fastpath)
#     370 def __init__(
#     371     self,
#     372     dims,
#    (...)    376     fastpath=False,
#     377 ):
#     378     """
#     379     Parameters
#     380     ----------
#    (...)    396         unrecognized encoding items.
#     397     """
# --> 398     super().__init__(
#     399         dims=dims, data=as_compatible_data(data, fastpath=fastpath), attrs=attrs
#     400     )
#     402     self._encoding: dict[Any, Any] | None = None
#     403     if encoding is not None:
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/namedarray/core.py:261, in NamedArray.__init__(self, dims, data, attrs)
#     254 def __init__(
#     255     self,
#     256     dims: _DimsLike,
#     257     data: duckarray[Any, _DType_co],
#     258     attrs: _AttrsLike = None,
#     259 ):
#     260     self._data = data
# --> 261     self._dims = self._parse_dimensions(dims)
#     262     self._attrs = dict(attrs) if attrs else None
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/namedarray/core.py:505, in NamedArray._parse_dimensions(self, dims)
#     503 dims = (dims,) if isinstance(dims, str) else tuple(dims)
#     504 if len(dims) != self.ndim:
# --> 505     raise ValueError(
#     506         f"dimensions {dims} must have the same length as the "
#     507         f"number of data dimensions, ndim={self.ndim}"
#     508     )
#     509 if len(set(dims)) < len(dims):
#     510     repeated_dims = {d for d in dims if dims.count(d) > 1}
#
# ValueError: dimensions ('lat', 'lon') must have the same length as the number of data dimensions, ndim=0

# %%
dist.min()
# Out:
# <xarray.DataArray 'tmmn' ()> Size: 8B
# array(164032.74653744)

# %%
"""
Author: Sydney Smith
Date Created: August 25, 2026
"""

from datetime import datetime
import glob
from loguru import logger
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from pathlib import Path
import sys
import xarray as xr

# ==================================
# - Establish Relative File Path - 
# ==================================

current_dir = Path(__file__).resolve().parent
parent_dir = current_dir.parent

# Import custom python modules from other directories
sys.path.append(str(parent_dir.parent.parent))
from from_savanna.nclcmaps import cmap

sys.path.append(str(parent_dir))
from old.temporal_chunks import open_or_skip, get_fpaths

sys.path.append(str(current_dir))
from spatial_chunks import fix_time_coord

var = 'tmmn'
obs_path = glob.glob(str(parent_dir / 'gridMET' / f'*{var}*.nc'))
ds = xr.open_dataset(obs_path[0], decode_times = False)

lat = 40.788
lon = -111.978

# Select single array along time dim to reduce ds size
lat_2d = ds[var].isel(time = 0, drop = True)
lon_2d = ds[var].isel(time = 0, drop = True)

# Find the vector distance from the coordinates passed to every coordinate pair on the dataset's grid
dist = (lat_2d - (lat)) ** 2 + (lon_2d - (lon)) ** 2

# Find the min distance and pull out its x and y index values
dist_min = dist.min(keep_attrs = True)
logger.info(f'Point selected is {dist_min} from {lat}, {lon}.')
y_idx, x_idx = np.unravel_index(dist_min, dist.shape)
logger.info(f'Min distance is located at {x_idx}, {y_idx}.')

# SPull grid's spatial dims dynamically
spatial_dims = ds['lat'].dims

# Select min distance grid point using isel
point_data = ds.isel({
    spatial_dims[0]: y_idx,
    spatial_dims[1]: x_idx
}).squeeze()
# Out:
# 20:58:47 |     INFO | __main__:<module>:line 51 - Point selected is <xarray.DataArray 'tmmn' ()> Size: 8B
# array(164032.74653744) from 40.788, -111.978.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 52
#      50 dist_min = dist.min(keep_attrs = True)
#      51 logger.info(f'Point selected is {dist_min} from {lat}, {lon}.')
# ---> 52 y_idx, x_idx = np.unravel_index(dist_min, dist.shape)
#      53 logger.info(f'Min distance is located at {x_idx}, {y_idx}.')
#      55 # SPull grid's spatial dims dynamically
#
# TypeError: only int indices permitted

# %%
dist_min
# Out:
# <xarray.DataArray 'tmmn' ()> Size: 8B
# array(164032.74653744)

# %%
dist.argmin()
# Out:
# /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/dataarray.py:6318: FutureWarning: Behaviour of argmin/argmax with neither dim nor axis argument will change to return a dict of indices of each dimension. To get a single, flat index, please use np.argmin(da.data) or np.argmax(da.data) instead of da.argmin() or da.argmax().
#   result = self.variable.argmin(dim, axis, keep_attrs, skipna)
# <xarray.DataArray 'tmmn' ()> Size: 8B
# array(9979)

# %%
dist
# Out:
# <xarray.DataArray 'tmmn' (lat: 111, lon: 90)> Size: 80kB
# array([[187219.30153138, 187464.75231886, 186427.41533223, ...,
#         188089.82895355, 187118.46478935, 187893.16236351],
#        [186587.78341134, 187232.69012382, 186687.80196483, ...,
#         186937.20918498, 186039.32796085, 186995.9890997 ],
#        [186227.44616008, 186988.32300968, 186343.90561145, ...,
#         185444.69040631, 184900.89864133, 186352.86738269],
#        ...,
#        [183815.75405522, 183731.98748553, 183769.29280911, ...,
#         167036.54168011, 167504.23920636, 169596.23774645],
#        [182754.11891886, 182597.54651803, 182573.05563337, ...,
#         165635.83213153, 167388.48137444, 169031.01911704],
#        [181926.59234799, 181720.38196904, 181740.37010886, ...,
#         164857.74957333, 167328.66835973, 168426.62795921]],
#       shape=(111, 90))
# Dimensions without coordinates: lat, lon

# %%
"""
Author: Sydney Smith
Date Created: August 25, 2026
"""

from datetime import datetime
import glob
from loguru import logger
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from pathlib import Path
import sys
import xarray as xr

# ==================================
# - Establish Relative File Path - 
# ==================================

current_dir = Path(__file__).resolve().parent
parent_dir = current_dir.parent

# Import custom python modules from other directories
sys.path.append(str(parent_dir.parent.parent))
from from_savanna.nclcmaps import cmap

sys.path.append(str(parent_dir))
from old.temporal_chunks import open_or_skip, get_fpaths

sys.path.append(str(current_dir))
from spatial_chunks import fix_time_coord

var = 'tmmn'
obs_path = glob.glob(str(parent_dir / 'gridMET' / f'*{var}*.nc'))
ds = xr.open_dataset(obs_path[0], decode_times = False)

lat = 40.788
lon = -111.978

# Select single array along time dim to reduce ds size
lat_2d = ds[var].isel(time = 0, drop = True)
lon_2d = ds[var].isel(time = 0, drop = True)

# Find the vector distance from the coordinates passed to every coordinate pair on the dataset's grid
dist = (lat_2d - (lat)) ** 2 + (lon_2d - (lon)) ** 2

# Find the min distance and pull out its x and y index values
dist_min = dist.argmin()
logger.info(f'Point selected is {dist_min} from {lat}, {lon}.')
y_idx, x_idx = np.unravel_index(dist_min, dist.shape)
logger.info(f'Min distance is located at {x_idx}, {y_idx}.')

# SPull grid's spatial dims dynamically
spatial_dims = ds['lat'].dims

# Select min distance grid point using isel
point_data = ds.isel({
    spatial_dims[0]: y_idx,
    spatial_dims[1]: x_idx
}).squeeze()
# Out:
# /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/dataarray.py:6318: FutureWarning: Behaviour of argmin/argmax with neither dim nor axis argument will change to return a dict of indices of each dimension. To get a single, flat index, please use np.argmin(da.data) or np.argmax(da.data) instead of da.argmin() or da.argmax().
#   result = self.variable.argmin(dim, axis, keep_attrs, skipna)
# 21:01:39 |     INFO | __main__:<module>:line 51 - Point selected is <xarray.DataArray 'tmmn' ()> Size: 8B
# array(9979) from 40.788, -111.978.
# 21:01:39 |     INFO | __main__:<module>:line 53 - Min distance is located at 79, 110.

# %%
y_idx
# Out:
# np.int64(110)

# %%
spatial_dims
# Out:
# ('time', 'south_north', 'east_west', 'west_east')

# %%
point_data
# Out:
# <xarray.Dataset> Size: 145kB
# Dimensions:  (lat: 111, lon: 90, east_west: 90, west_east: 90)
# Coordinates:
#     lat      (east_west, west_east) float32 32kB ...
#     lon      (east_west, west_east) float32 32kB ...
#     time     int64 8B 55
# Dimensions without coordinates: east_west, west_east
# Data variables:
#     tmmn     (lat, lon) float64 80kB ...

# %%
point_data.lat
# Out:
# <xarray.DataArray 'lat' (east_west: 90, west_east: 90)> Size: 32kB
# [8100 values with dtype=float32]
# Coordinates:
#     lat      (east_west, west_east) float32 32kB ...
#     lon      (east_west, west_east) float32 32kB ...
#     time     int64 8B 55
# Dimensions without coordinates: east_west, west_east

# %%
point_data.lat.values
# Out:
# array([[42.058174, 42.058174, 42.058174, ..., 42.058174, 42.058174,
#         42.058174],
#        [42.05909 , 42.05909 , 42.05909 , ..., 42.05909 , 42.05909 ,
#         42.05909 ],
#        [42.05998 , 42.05998 , 42.05998 , ..., 42.05998 , 42.05998 ,
#         42.05998 ],
#        ...,
#        [42.062523, 42.062523, 42.062523, ..., 42.062523, 42.062523,
#         42.062523],
#        [42.06169 , 42.06169 , 42.06169 , ..., 42.06169 , 42.06169 ,
#         42.06169 ],
#        [42.060844, 42.060844, 42.060844, ..., 42.060844, 42.060844,
#         42.060844]], shape=(90, 90), dtype=float32)

# %%
point_data.lon.values
# Out:
# array([[-114.22894 , -114.22894 , -114.22894 , ..., -114.22894 ,
#         -114.22894 , -114.22894 ],
#        [-114.18051 , -114.18051 , -114.18051 , ..., -114.18051 ,
#         -114.18051 , -114.18051 ],
#        [-114.132065, -114.132065, -114.132065, ..., -114.132065,
#         -114.132065, -114.132065],
#        ...,
#        [-110.01326 , -110.01326 , -110.01326 , ..., -110.01326 ,
#         -110.01326 , -110.01326 ],
#        [-109.96481 , -109.96481 , -109.96481 , ..., -109.96481 ,
#         -109.96481 , -109.96481 ],
#        [-109.91638 , -109.91638 , -109.91638 , ..., -109.91638 ,
#         -109.91638 , -109.91638 ]], shape=(90, 90), dtype=float32)

# %%
"""
Author: Sydney Smith
Date Created: August 25, 2026
"""

from datetime import datetime
import glob
from loguru import logger
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from pathlib import Path
import sys
import xarray as xr

# ==================================
# - Establish Relative File Path - 
# ==================================

current_dir = Path(__file__).resolve().parent
parent_dir = current_dir.parent

# Import custom python modules from other directories
sys.path.append(str(parent_dir.parent.parent))
from from_savanna.nclcmaps import cmap

sys.path.append(str(parent_dir))
from old.temporal_chunks import open_or_skip, get_fpaths

sys.path.append(str(current_dir))
from spatial_chunks import fix_time_coord

var = 'tmmn'
obs_path = glob.glob(str(parent_dir / 'gridMET' / f'*{var}*.nc'))
ds = xr.open_dataset(obs_path[0], decode_times = False)

lat = 40.788
lon = -111.978

# Select single array along time dim to reduce ds size
lat_2d = ds[var].isel(time = 0, drop = True)
lon_2d = ds[var].isel(time = 0, drop = True)

# Find the vector distance from the coordinates passed to every coordinate pair on the dataset's grid
dist = (lat_2d - (lat)) ** 2 + (lon_2d - (lon)) ** 2

# Find the min distance and pull out its x and y index values
dist_min = dist.argmin()
logger.info(f'Point selected is {dist_min} from {lat}, {lon}.')
y_idx, x_idx = np.unravel_index(dist_min, dist.shape)
logger.info(f'Min distance is located at {x_idx}, {y_idx}.')

# SPull grid's spatial dims dynamically
spatial_dims = ds['lat'].dims

# Select min distance grid point using isel
point_data = ds.isel({
    spatial_dims[0]: y_idx,
    spatial_dims[1]: x_idx
}).squeeze()

logger.info(f'New lat: {float(point_data["lat"][0])}')
logger.info(f'New lon: {float(point_data["lon"][0])}')
# Out:
# /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/dataarray.py:6318: FutureWarning: Behaviour of argmin/argmax with neither dim nor axis argument will change to return a dict of indices of each dimension. To get a single, flat index, please use np.argmin(da.data) or np.argmax(da.data) instead of da.argmin() or da.argmax().
#   result = self.variable.argmin(dim, axis, keep_attrs, skipna)
# 21:03:09 |     INFO | __main__:<module>:line 51 - Point selected is <xarray.DataArray 'tmmn' ()> Size: 8B
# array(9979) from 40.788, -111.978.
# 21:03:09 |     INFO | __main__:<module>:line 53 - Min distance is located at 79, 110.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 64
#      58 # Select min distance grid point using isel
#      59 point_data = ds.isel({
#      60     spatial_dims[0]: y_idx,
#      61     spatial_dims[1]: x_idx
#      62 }).squeeze()
# ---> 64 logger.info(f'New lat: {float(point_data["lat"][0])}')
#      65 logger.info(f'New lon: {float(point_data["lon"][0])}')
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/common.py:158, in AbstractArray.__float__(self)
#     157 def __float__(self: Any) -> float:
# --> 158     return float(self.values)
#
# TypeError: only 0-dimensional arrays can be converted to Python scalars

# %%
point_data.lat.values[0]
# Out:
# array([42.058174, 42.058174, 42.058174, 42.058174, 42.058174, 42.058174,
#        42.058174, 42.058174, 42.058174, 42.058174, 42.058174, 42.058174,
#        42.058174, 42.058174, 42.058174, 42.058174, 42.058174, 42.058174,
#        42.058174, 42.058174, 42.058174, 42.058174, 42.058174, 42.058174,
#        42.058174, 42.058174, 42.058174, 42.058174, 42.058174, 42.058174,
#        42.058174, 42.058174, 42.058174, 42.058174, 42.058174, 42.058174,
#        42.058174, 42.058174, 42.058174, 42.058174, 42.058174, 42.058174,
#        42.058174, 42.058174, 42.058174, 42.058174, 42.058174, 42.058174,
#        42.058174, 42.058174, 42.058174, 42.058174, 42.058174, 42.058174,
#        42.058174, 42.058174, 42.058174, 42.058174, 42.058174, 42.058174,
#        42.058174, 42.058174, 42.058174, 42.058174, 42.058174, 42.058174,
#        42.058174, 42.058174, 42.058174, 42.058174, 42.058174, 42.058174,
#        42.058174, 42.058174, 42.058174, 42.058174, 42.058174, 42.058174,
#        42.058174, 42.058174, 42.058174, 42.058174, 42.058174, 42.058174,
#        42.058174, 42.058174, 42.058174, 42.058174, 42.058174, 42.058174],
#       dtype=float32)

# %%
point_data.lat.values[0][0]
# Out:
# np.float32(42.058174)

# %%
"""
Author: Sydney Smith
Date Created: August 25, 2026
"""

from datetime import datetime
import glob
from loguru import logger
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
from pathlib import Path
import sys
import xarray as xr

# ==================================
# - Establish Relative File Path - 
# ==================================

current_dir = Path(__file__).resolve().parent
parent_dir = current_dir.parent

# Import custom python modules from other directories
sys.path.append(str(parent_dir.parent.parent))
from from_savanna.nclcmaps import cmap

sys.path.append(str(parent_dir))
from old.temporal_chunks import open_or_skip, get_fpaths

sys.path.append(str(current_dir))
from spatial_chunks import fix_time_coord

var = 'tmmn'
obs_path = glob.glob(str(parent_dir / 'gridMET' / f'*{var}*.nc'))
ds = xr.open_dataset(obs_path[0], decode_times = False)

lat = 40.788
lon = -111.978

# Select single array along time dim to reduce ds size
lat_2d = ds[var].isel(time = 0, drop = True)
lon_2d = ds[var].isel(time = 0, drop = True)

# Find the vector distance from the coordinates passed to every coordinate pair on the dataset's grid
dist = (lat_2d - (lat)) ** 2 + (lon_2d - (lon)) ** 2

# Find the min distance and pull out its x and y index values
dist_min = dist.argmin()
logger.info(f'Point selected is {dist_min} from {lat}, {lon}.')
y_idx, x_idx = np.unravel_index(dist_min, dist.shape)
logger.info(f'Min distance is located at {x_idx}, {y_idx}.')

# SPull grid's spatial dims dynamically
spatial_dims = ds['lat'].dims

# Select min distance grid point using isel
point_data = ds.isel({
    spatial_dims[0]: y_idx,
    spatial_dims[1]: x_idx
}).squeeze()

logger.info(f'New lat: {float(point_data.lat.values[0][0])}')
logger.info(f'New lon: {float(point_data.lon.values[0][0])}')
# Out:
# /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/dataarray.py:6318: FutureWarning: Behaviour of argmin/argmax with neither dim nor axis argument will change to return a dict of indices of each dimension. To get a single, flat index, please use np.argmin(da.data) or np.argmax(da.data) instead of da.argmin() or da.argmax().
#   result = self.variable.argmin(dim, axis, keep_attrs, skipna)
# 21:03:50 |     INFO | __main__:<module>:line 51 - Point selected is <xarray.DataArray 'tmmn' ()> Size: 8B
# array(9979) from 40.788, -111.978.
# 21:03:50 |     INFO | __main__:<module>:line 53 - Min distance is located at 79, 110.
# 21:03:50 |     INFO | __main__:<module>:line 64 - New lat: 42.05817413330078
# 21:03:50 |     INFO | __main__:<module>:line 65 - New lon: -114.22894287109375

# %%
obs
# Out:
# <xarray.Dataset> Size: 159GB
# Dimensions:  (time: 21914, lat: 111, lon: 90, south_north: 111, east_west: 90,
#               west_east: 90)
# Coordinates:
#   * time     (time) int64 175kB 0 0 1 1 2 2 ... 10954 10955 10955 10956 10956
#     lat      (time, south_north, east_west, west_east) float32 79GB ...
#     lon      (time, south_north, east_west, west_east) float32 79GB ...
# Dimensions without coordinates: south_north, east_west, west_east
# Data variables:
#     tmmn     (time, lat, lon) float64 2GB ...

# %%
obs.lat.values
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 obs.lat.values
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/dataarray.py:803, in DataArray.values(self)
#     790 @property
#     791 def values(self) -> np.ndarray:
#     792     """
#     793     The array's data converted to numpy.ndarray.
#     794
#    (...)    801     to this array may be reflected in the DataArray as well.
#     802     """
# --> 803     return self.variable.values
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/variable.py:555, in Variable.values(self)
#     552 @property
#     553 def values(self) -> np.ndarray:
#     554     """The variable's data as a numpy.ndarray"""
# --> 555     return _as_array_or_item(self._data)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/variable.py:335, in _as_array_or_item(data)
#     321 def _as_array_or_item(data):
#     322     """Return the given values as a numpy array, or as an individual item if
#     323     it's a 0d datetime64 or timedelta64 array.
#     324
#    (...)    333     TODO: remove this (replace with np.asarray) once these issues are fixed
#     334     """
# --> 335     data = np.asarray(data)
#     336     if data.ndim == 0:
#     337         kind = data.dtype.kind
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/indexing.py:604, in ExplicitlyIndexed.__array__(self, dtype, copy)
#     599 def __array__(
#     600     self, dtype: DTypeLike | None = None, /, *, copy: bool | None = None
#     601 ) -> np.ndarray:
#     602     # Leave casting to an array up to the underlying array type.
#     603     if Version(np.__version__) >= Version("2.0.0"):
# --> 604         return np.asarray(self.get_duck_array(), dtype=dtype, copy=copy)
#     605     else:
#     606         return np.asarray(self.get_duck_array(), dtype=dtype)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/indexing.py:970, in MemoryCachedArray.get_duck_array(self)
#     969 def get_duck_array(self):
# --> 970     duck_array = self.array.get_duck_array()
#     971     # ensure the array object is cached in-memory
#     972     self.array = as_indexable(duck_array)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/indexing.py:924, in CopyOnWriteArray.get_duck_array(self)
#     923 def get_duck_array(self):
# --> 924     return self.array.get_duck_array()
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/indexing.py:764, in LazilyIndexedArray.get_duck_array(self)
#     761 from xarray.backends.common import BackendArray
#     763 if isinstance(self.array, BackendArray):
# --> 764     array = self.array[self.key]
#     765 else:
#     766     array = apply_indexer(self.array, self.key)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:117, in NetCDF4ArrayWrapper.__getitem__(self, key)
#     116 def __getitem__(self, key):
# --> 117     return indexing.explicit_indexing_adapter(
#     118         key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#     119     )
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/indexing.py:1156, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#    1134 """Support explicit indexing by delegating to a raw indexing method.
#    1135
#    1136 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)   1153 Indexing result, in the form of a duck numpy-array.
#    1154 """
#    1155 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1156 result = raw_indexing_method(raw_key.tuple)
#    1157 if numpy_indices.tuple:
#    1158     # index the loaded duck array
#    1159     indexable = as_indexable(result)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:130, in NetCDF4ArrayWrapper._getitem(self, key)
#     128     with self.datastore.lock:
#     129         original_array = self.get_array(needs_lock=False)
# --> 130         array = getitem(original_array, key)
#     131 except IndexError as err:
#     132     # Catch IndexError in netCDF4 and return a more informative
#     133     # error message.  This is most often called when an unsorted
#     134     # indexer is used before the data is loaded from disk.
#     135     msg = (
#     136         "The indexing operation you are attempting to perform "
#     137         "is not valid on netCDF4.Variable object. Try loading "
#     138         "your data into memory first by calling .load()."
#     139     )
#
# File src/netCDF4/_netCDF4.pyx:5089
# -> 5089 'Could not get source, probably due dynamically evaluated source code.'
#
# MemoryError: Unable to allocate 73.4 GiB for an array with shape (21914, 111, 90, 90) and data type float32

# %%
obs.lat
# Out:
# <xarray.DataArray 'lat' (time: 21914, south_north: 111, east_west: 90,
#                          west_east: 90)> Size: 79GB
# [19702877400 values with dtype=float32]
# Coordinates:
#   * time     (time) int64 175kB 0 0 1 1 2 2 ... 10954 10955 10955 10956 10956
#     lat      (time, south_north, east_west, west_east) float32 79GB ...
#     lon      (time, south_north, east_west, west_east) float32 79GB ...
# Dimensions without coordinates: south_north, east_west, west_east

# %%
obs.lat.values
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 obs.lat.values
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/dataarray.py:803, in DataArray.values(self)
#     790 @property
#     791 def values(self) -> np.ndarray:
#     792     """
#     793     The array's data converted to numpy.ndarray.
#     794
#    (...)    801     to this array may be reflected in the DataArray as well.
#     802     """
# --> 803     return self.variable.values
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/variable.py:555, in Variable.values(self)
#     552 @property
#     553 def values(self) -> np.ndarray:
#     554     """The variable's data as a numpy.ndarray"""
# --> 555     return _as_array_or_item(self._data)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/variable.py:335, in _as_array_or_item(data)
#     321 def _as_array_or_item(data):
#     322     """Return the given values as a numpy array, or as an individual item if
#     323     it's a 0d datetime64 or timedelta64 array.
#     324
#    (...)    333     TODO: remove this (replace with np.asarray) once these issues are fixed
#     334     """
# --> 335     data = np.asarray(data)
#     336     if data.ndim == 0:
#     337         kind = data.dtype.kind
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/indexing.py:604, in ExplicitlyIndexed.__array__(self, dtype, copy)
#     599 def __array__(
#     600     self, dtype: DTypeLike | None = None, /, *, copy: bool | None = None
#     601 ) -> np.ndarray:
#     602     # Leave casting to an array up to the underlying array type.
#     603     if Version(np.__version__) >= Version("2.0.0"):
# --> 604         return np.asarray(self.get_duck_array(), dtype=dtype, copy=copy)
#     605     else:
#     606         return np.asarray(self.get_duck_array(), dtype=dtype)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/indexing.py:970, in MemoryCachedArray.get_duck_array(self)
#     969 def get_duck_array(self):
# --> 970     duck_array = self.array.get_duck_array()
#     971     # ensure the array object is cached in-memory
#     972     self.array = as_indexable(duck_array)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/indexing.py:924, in CopyOnWriteArray.get_duck_array(self)
#     923 def get_duck_array(self):
# --> 924     return self.array.get_duck_array()
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/indexing.py:764, in LazilyIndexedArray.get_duck_array(self)
#     761 from xarray.backends.common import BackendArray
#     763 if isinstance(self.array, BackendArray):
# --> 764     array = self.array[self.key]
#     765 else:
#     766     array = apply_indexer(self.array, self.key)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:117, in NetCDF4ArrayWrapper.__getitem__(self, key)
#     116 def __getitem__(self, key):
# --> 117     return indexing.explicit_indexing_adapter(
#     118         key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#     119     )
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/core/indexing.py:1156, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#    1134 """Support explicit indexing by delegating to a raw indexing method.
#    1135
#    1136 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)   1153 Indexing result, in the form of a duck numpy-array.
#    1154 """
#    1155 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1156 result = raw_indexing_method(raw_key.tuple)
#    1157 if numpy_indices.tuple:
#    1158     # index the loaded duck array
#    1159     indexable = as_indexable(result)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/miniforge3_envs/olympics/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:130, in NetCDF4ArrayWrapper._getitem(self, key)
#     128     with self.datastore.lock:
#     129         original_array = self.get_array(needs_lock=False)
# --> 130         array = getitem(original_array, key)
#     131 except IndexError as err:
#     132     # Catch IndexError in netCDF4 and return a more informative
#     133     # error message.  This is most often called when an unsorted
#     134     # indexer is used before the data is loaded from disk.
#     135     msg = (
#     136         "The indexing operation you are attempting to perform "
#     137         "is not valid on netCDF4.Variable object. Try loading "
#     138         "your data into memory first by calling .load()."
#     139     )
#
# File src/netCDF4/_netCDF4.pyx:5089
# -> 5089 'Could not get source, probably due dynamically evaluated source code.'
#
# MemoryError: Unable to allocate 73.4 GiB for an array with shape (21914, 111, 90, 90) and data type float32
